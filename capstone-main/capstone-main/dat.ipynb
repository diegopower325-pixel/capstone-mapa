# %%
import pandas as pd

# %%
dat = pd.read_csv("intervenciones_registradas.csv")

# %%
dat.head()
# Out:
#   Dirección de la Orden de Trabajo de Workforce Fecha Reclamo  \
# 0                Chivilcan con Villama (Puente)    2026-06-18
# 1                Chivilcan con Villama (Puente)    2026-06-09
#
#   Fecha Intervención  Km Inicio  Km Termino  Diferencia Km  N° Rejillas  \
# 0         2026-06-18         50          60             10            0
# 1         2026-06-18         30          50             20            5
#
#    N° Cámaras  N° Ductos  N° de cargas de agua  ...  \
# 0           0          2                     0  ...
# 1           2          2                     3  ...
#
#    N° de descargas de sedimentos  Cantidad total de sedimentos (Lt)  \
# 0                              6                               2500
# 1                              3                               3000
#
#    Macrosector  Unidad Vecinal Coordenada X Coordenada Y       Fecha_datetime  \
# 0     AMANECER           5 SUR   -72.619728   -38.713014  2026-06-18 00:00:00
# ...
